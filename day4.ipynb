# %%
a=1
b=1

# %%
print(a)
print(b)
print(c)
# Out:
# 1
# 1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 print(a)
#       2 print(b)
# ----> 3 print(c)
#
# NameError: name 'c' is not defined

# %%
id(a)
# Out:
# 140719199736616

# %%
id(b)
# Out:
# 140719199736616

# %%
print('hello world')
# Out:
# hello world

# %%
open('test.txt', 'r').read()
# Out:
# 'hey there how are you?'

# %%
b=2

# %%
id(b)
# Out:
# 140719199736648

# %%
c=2

# %%
id(c)
# Out:
# 140719199736648

# %%
# string methods

# %%
"he's my colleague"
# Out:
# "he's my colleague"

# %%
'he is "my" colleague'
# Out:
# 'he is "my" colleague'

# %%
'''hi's "my" colleague'''
# Out:
# 'hi\'s "my" colleague'

# %%
print('''hi's "my" colleague''')
# Out:
# hi's "my" colleague

# %%
'''hey there
how are you?'''
# Out:
# 'hey there \nhow are you?'

# %%
print('''hey there
how are you?''')
# Out:
# hey there
# how are you?

# %%
r'hey there \nhow are you?'
# Out:
# 'hey there \\nhow are you?'
