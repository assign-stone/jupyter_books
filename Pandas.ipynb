# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df1=pd.DataFrame({'lkey':['foo','bar','baz','foo'],
                 'value':[1,2,3,4]})
df2=pd.DataFrame({'rkey':['bar','foo','foz','baz'],
                 'value':[2,1,3,4]})
df1.merge(df2)
# Out:
#   lkey  value rkey
# 0  foo      1  foo
# 1  bar      2  bar
# 2  baz      3  foz
# 3  foo      4  baz

# %%
import pandas as pd

df1=pd.DataFrame({'lkey':['foo','bar','baz','foo'],
                 'id':[1,2,3,4]})
df2=pd.DataFrame({'rkey':['bar','foo','foz','baz'],
                 'uid':[2,1,3,4]})
df1.merge(df2,left_on*'id',right_on*'uid')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 7>()
#       3 df1=pd.DataFrame({'lkey':['foo','bar','baz','foo'],
#       4                  'id':[1,2,3,4]})
#       5 df2=pd.DataFrame({'rkey':['bar','foo','foz','baz'],
#       6                  'uid':[2,1,3,4]})
# ----> 7 df1.merge(df2,left_on*'id',right_on*'uid')
#
# NameError: name 'left_on' is not defined

# %%
import pandas as pd
import numpy as np

df=pd.DataFrame([['computer',1,'name1'],['computer',2,'name2'],['electrical',1,'name1'],['electrical',2,'name3']],
               columns=['department','roll','name'])
df
# Out:
#    department  roll   name
# 0    computer     1  name1
# 1    computer     2  name2
# 2  electrical     1  name1
# 3  electrical     2  name3

# %%
array=[
    ["Avi","Sunita","Alex","Agni"],
    [86,85,81,85],
    [1001,1002,1003,1004]
]
index=pd.MultiIndex.from_arrays(array,names=['names','marks','rollno'])
index
# Out:
# MultiIndex([(   'Avi', 86, 1001),
#             ('Sunita', 85, 1002),
#             (  'Alex', 81, 1003),
#             (  'Agni', 85, 1004)],
#            names=['names', 'marks', 'rollno'])

# %%
tuples=[('bar','one'),('bar','two'),('baz','one'),('baz','two'),('foo','one'),('foo','two'),('qux','one'),('qux','two')]
index2=pd.MultiIndex.from_tuples(tuples,names=['name','conuts'])
index2
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            names=['name', 'conuts'])

# %%
tuples=[('Avi',86),('babita',77),('Yukri',66),('raz',88)]
index2=pd.MultiIndex.from_tuples(tuples,names=['name','marks'])
index2
# Out:
# MultiIndex([(   'Avi', 86),
#             ('babita', 77),
#             ( 'Yukri', 66),
#             (   'raz', 88)],
#            names=['name', 'marks'])

# %%
iterables=[['bar','baz','foo','maz'],["one","two"]]
index3=pd.MultiIndex.from_product(iterables,names=['first','second'])
index3
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('maz', 'one'),
#             ('maz', 'two')],
#            names=['first', 'second'])

# %%
iterables=[['computer','electrical'],[1,2,3]]
index3=pd.MultiIndex.from_product(iterables,names=['Department','Roll'])
index3
# Out:
# MultiIndex([(  'computer', 1),
#             (  'computer', 2),
#             (  'computer', 3),
#             ('electrical', 1),
#             ('electrical', 2),
#             ('electrical', 3)],
#            names=['Department', 'Roll'])

# %%
df_index=pd.DataFrame([['bar','one'],['bar','two'],['baz','one'],
                       ['baz','two'],['foo','one'],['foo','two'],
                       ['qux','one'],['qux','two']],
                      columns=['first','second'])
index4=pd.MultiIndex.from_frame(df=df_index)
index4
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            names=['first', 'second'])

# %%
df_index=pd.DataFrame([['Avi',86],['babita',77],['Yukri',66],['raz',88]],
         columns=['names','marks'])
index4=pd.MultiIndex.from_frame(df=df_index)
index4
# Out:
# MultiIndex([(   'Avi', 86),
#             ('babita', 77),
#             ( 'Yukri', 66),
#             (   'raz', 88)],
#            names=['names', 'marks'])

# %%
df=pd.DataFrame([['computer',1,'avi'],['computer',2,'sheela'],['electrical',1,'Akshita'],['electrical',2,'Himani']],
               columns=['department','roll','name'])
df.set_index(['department','roll'])
# Out:
#                     name
# department roll
# computer   1         avi
#            2      sheela
# electrical 1     Akshita
#            2      Himani

# %%
df=pd.DataFrame(np.random.random(8),index=index)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [59], in <cell line: 1>()
# ----> 1 df=pd.DataFrame(np.random.random(8),index=index)
#       2 df
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:694, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     684         mgr = dict_to_mgr(
#     685             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     686             # attribute "name"
#    (...)
#     691             typ=manager,
#     692         )
#     693     else:
# --> 694         mgr = ndarray_to_mgr(
#     695             data,
#     696             index,
#     697             columns,
#     698             dtype=dtype,
#     699             copy=copy,
#     700             typ=manager,
#     701         )
#     703 # For data is list-like, or Iterable (will consume into list)
# ...

# %%
index=[[11,17,15,85],[1,2,5,8]]
arry=pd.MultiIndex.from_arrays(index,
                              names=['id','roll'])
df=pd.DataFrame(['name1','name2','name3','name4'],
                    index=arry,columns=['names'])
df
# Out:
#          names
# id roll
# 11 1     name1
# 17 2     name2
# 15 5     name3
# 85 8     name4

# %%
iterable=[['bar','car','mar','npp'],['two','one']]
itera=pd.MultiIndex.from_product(iterable,
                                 names=['first','second'])
itera
# Out:
# MultiIndex([('bar', 'two'),
#             ('bar', 'one'),
#             ('car', 'two'),
#             ('car', 'one'),
#             ('mar', 'two'),
#             ('mar', 'one'),
#             ('npp', 'two'),
#             ('npp', 'one')],
#            names=['first', 'second'])

# %%
iterable=[['bar','car','mar','npp'],['two','one']]
itera=pd.MultiIndex.from_product(iterable,
                                 names=['first','second'])
itera.sortlevel()
# Out:
# (MultiIndex([('bar', 'one'),
#              ('bar', 'two'),
#              ('car', 'one'),
#              ('car', 'two'),
#              ('mar', 'one'),
#              ('mar', 'two'),
#              ('npp', 'one'),
#              ('npp', 'two')],
#             names=['first', 'second']),
#  array([1, 0, 3, 2, 5, 4, 7, 6], dtype=int64))

# %%
itera.sortlevel(level=['first'],sort_remaining=False)
# Out:
# (MultiIndex([('bar', 'two'),
#              ('bar', 'one'),
#              ('car', 'two'),
#              ('car', 'one'),
#              ('mar', 'two'),
#              ('mar', 'one'),
#              ('npp', 'two'),
#              ('npp', 'one')],
#             names=['first', 'second']),
#  array([0, 1, 2, 3, 4, 5, 6, 7], dtype=int64))

# %%
itera.sortlevel(level=['second'],ascending=False)
# Out:
# (MultiIndex([('npp', 'two'),
#              ('mar', 'two'),
#              ('car', 'two'),
#              ('bar', 'two'),
#              ('npp', 'one'),
#              ('mar', 'one'),
#              ('car', 'one'),
#              ('bar', 'one')],
#             names=['first', 'second']),
#  array([6, 4, 2, 0, 7, 5, 3, 1], dtype=int64))

# %%
import numpy as np
index=[['bar','car','mar','npp'],['two','one']]
df=pd.DataFrame(np.random.randn(8),
               index=index)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [68], in <cell line: 3>()
#       1 import numpy as np
#       2 index=[['bar','car','mar','npp'],['two','one']]
# ----> 3 df=pd.DataFrame(np.random.randn(8),
#       4                index=index)
#       5 df
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:694, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     684         mgr = dict_to_mgr(
#     685             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     686             # attribute "name"
#    (...)
#     691             typ=manager,
#     692         )
#     693     else:
# --> 694         mgr = ndarray_to_mgr(
#     695             data,
#     696             index,
#     697             columns,
#     698             dtype=dtype,
#     699             copy=copy,
#     700             typ=manager,
# ...

# %%
multi_col=pd.MultiIndex.from_tuples([('wind','mph'),('wind','m/s')])
df_stack=pd.DataFrame([[13,5.5],[19,8.5]],
                     index=['london','oxford'],
                     columns=multi_col)
df_stack
# Out:
#        wind
#         mph  m/s
# london   13  5.5
# oxford   19  8.5

# %%
multi_col=pd.MultiIndex.from_tuples([('wind','mph'),('wind','m/s')])
df_stack=pd.DataFrame([[13,5.5],[19,8.5]],
                     index=['london','oxford'],
                     columns=multi_col)
df_stack.stack(level=1)
# Out:
#             wind
# london m/s   5.5
#        mph  13.0
# oxford m/s   8.5
#        mph  19.0

# %%
index=pd.MultiIndex.from_tuples([
    ('oxford','weather','01-01-2022'),
    ('oxford','temp','01-01-2022'),
    ('oxford','weather','02-01-2022'),
    ('oxford','temp','02-01-2022'),
    ('london','weather','01-01-2022'),
    ('london','temp','01-01-2022'),
    ('london','weather','02-01-2022'),
    ('london','temp','02-01-2022'),
])
df_unstack=pd.DataFrame(['sunny',10,'shower',20,'shower',5,'sunny',8],
                       index=index,columns=["values"])
df_unstack
# Out:
#                            values
# oxford weather 01-01-2022   sunny
#        temp    01-01-2022      10
#        weather 02-01-2022  shower
#        temp    02-01-2022      20
# london weather 01-01-2022  shower
#        temp    01-01-2022       5
#        weather 02-01-2022   sunny
#        temp    02-01-2022       8

# %%
df1=pd.DataFrame([
    ['5/1/2017','newyork',65,56],
    ['5/2/2017','newyork',68,55],
    ['5/3/2017','newyork',69,45],
    ['5/1/2017','mumbai',70,56],
    ['5/2/2017','mumbai',75,66],
    ['5/3/2017','mumbai',65,46],
    ['5/1/2017','tokyo',77,70],
    ['5/2/2017','tokyo',88,89],
    ['5/3/2017','tokyo',52,87]],
    columns=['date','city','temp','humidity']
)
df1
# Out:
#        data     city  temp  humidity
# 0  5/1/2017  newyork    65        56
# 1  5/2/2017  newyork    68        55
# 2  5/3/2017  newyork    69        45
# 3  5/1/2017   mumbai    70        56
# 4  5/2/2017   mumbai    75        66
# 5  5/3/2017   mumbai    65        46
# 6  5/1/2017    tokyo    77        70
# 7  5/2/2017    tokyo    88        89
# 8  5/3/2017    tokyo    52        87

# %%
df1=pd.DataFrame([
    ['5/1/2017','newyork',65,56],
    ['5/2/2017','newyork',68,55],
    ['5/3/2017','newyork',69,45],
    ['5/1/2017','mumbai',70,56],
    ['5/2/2017','mumbai',75,66],
    ['5/3/2017','mumbai',65,46],
    ['5/1/2017','tokyo',77,70],
    ['5/2/2017','tokyo',88,89],
    ['5/3/2017','tokyo',52,87]],
    columns=['date','city','temp','humidity']
)
df1.pivot(index='date',columns='city',values='humidity')
# Out:
# city      mumbai  newyork  tokyo
# date
# 5/1/2017      56       56     70
# 5/2/2017      66       55     89
# 5/3/2017      46       45     87

# %%
df1=pd.DataFrame([
    ['5/1/2017','newyork',65,56],
    ['5/2/2017','newyork',68,55],
    ['5/3/2017','newyork',69,45],
    ['5/1/2017','mumbai',70,56],
    ['5/2/2017','mumbai',75,66],
    ['5/3/2017','mumbai',65,46],
    ['5/1/2017','tokyo',77,70],
    ['5/2/2017','tokyo',88,89],
    ['5/3/2017','tokyo',52,87]],
    columns=['date','city','temp','humidity']
)

df1.pivot(index='date',columns=['city','temp'],values=['humidity','temp'])
# Out:
#          humidity                                                     temp  \
# city      newyork             mumbai             tokyo             newyork
# temp           65    68    69     70    75    65    77    88    52      65
# date
# 5/1/2017     56.0   NaN   NaN   56.0   NaN   NaN  70.0   NaN   NaN    65.0
# 5/2/2017      NaN  55.0   NaN    NaN  66.0   NaN   NaN  89.0   NaN     NaN
# 5/3/2017      NaN   NaN  45.0    NaN   NaN  46.0   NaN   NaN  87.0     NaN
#
#
# city                 mumbai             tokyo
# temp        68    69     70    75    65    77    88    52
# date
# 5/1/2017   NaN   NaN   70.0   NaN   NaN  77.0   NaN   NaN
# 5/2/2017  68.0   NaN    NaN  75.0   NaN   NaN  88.0   NaN
# 5/3/2017   NaN  69.0    NaN   NaN  65.0   NaN   NaN  52.0

# %%
df2=pd.DataFrame([
    ['5/1/2017','newyork',65,56],
    ['5/2/2017','newyork',68,55],
    ['5/3/2017','newyork',69,45],
    ['5/1/2017','mumbai',70,56],
    ['5/2/2017','mumbai',75,66],
    ['5/3/2017','mumbai',65,46],
    ['5/1/2017','tokyo',77,70],
    ['5/2/2017','tokyo',88,89],
    ['5/3/2017','tokyo',52,87],
    ],
    columns=['date','city','temp','humidity']
)
df2
# Out:
#        date     city  temp  humidity
# 0  5/1/2017  newyork    65        56
# 1  5/2/2017  newyork    68        55
# 2  5/3/2017  newyork    69        45
# 3  5/1/2017   mumbai    70        56
# 4  5/2/2017   mumbai    75        66
# 5  5/3/2017   mumbai    65        46
# 6  5/1/2017    tokyo    77        70
# 7  5/2/2017    tokyo    88        89
# 8  5/3/2017    tokyo    52        87

# %%
df2=pd.DataFrame([
    ['5/1/2017','newyork',65,56],
    ['5/2/2017','newyork',68,55],
    ['5/3/2017','newyork',69,45],
    ['5/1/2017','mumbai',70,56],
    ['5/2/2017','mumbai',75,66],
    ['5/3/2017','mumbai',65,46],
    ['5/1/2017','tokyo',77,70],
    ['5/2/2017','tokyo',88,89],
    ['5/3/2017','tokyo',52,87],
    ],
    columns=['date','city','temp','humidity']
)
df2.pivot_table(index="city",columns='date')
# Out:
#         humidity                       temp
# date    5/1/2017 5/2/2017 5/3/2017 5/1/2017 5/2/2017 5/3/2017
# city
# mumbai        56       66       46       70       75       65
# newyork       56       55       45       65       68       69
# tokyo         70       89       87       77       88       52

# %%
df2=pd.DataFrame([
    ['5/1/2017','newyork',65,56],
    ['5/2/2017','newyork',68,55],
    ['5/3/2017','newyork',69,45],
    ['5/1/2017','mumbai',70,56],
    ['5/2/2017','mumbai',75,66],
    ['5/3/2017','mumbai',65,46],
    ['5/1/2017','tokyo',77,70],
    ['5/2/2017','tokyo',88,89],
    ['5/3/2017','tokyo',52,87],
    ],
    columns=['date','city','temp','humidity']
)
df2.pivot_table(index="city",columns='date',aggfunc="sum")
# Out:
#         humidity                       temp
# date    5/1/2017 5/2/2017 5/3/2017 5/1/2017 5/2/2017 5/3/2017
# city
# mumbai        56       66       46       70       75       65
# newyork       56       55       45       65       68       69
# tokyo         70       89       87       77       88       52

# %%
df2=pd.DataFrame([
    ['5/1/2017','newyork',65,56],
    ['5/2/2017','newyork',68,55],
    ['5/3/2017','newyork',69,45],
    ['5/1/2017','mumbai',70,56],
    ['5/2/2017','mumbai',75,66],
    ['5/3/2017','mumbai',65,46],
    ['5/1/2017','tokyo',77,70],
    ['5/2/2017','tokyo',88,89],
    ['5/3/2017','tokyo',52,87],
    ],
    columns=['date','city','temp','humidity']
)
df2.pivot_table(index="city",columns='date',aggfunc="sum",margins=True)
# Out:
#         humidity                            temp
# date    5/1/2017 5/2/2017 5/3/2017  All 5/1/2017 5/2/2017 5/3/2017  All
# city
# mumbai        56       66       46  168       70       75       65  210
# newyork       56       55       45  156       65       68       69  202
# tokyo         70       89       87  246       77       88       52  217
# All          182      210      178  570      212      231      186  629

# %%
df2=pd.DataFrame([
    ['5/1/2017','newyork',65,56],
    ['5/2/2017','newyork',68,55],
    ['5/3/2017','newyork',69,45],
    ['5/1/2017','mumbai',70,56],
    ['5/2/2017','mumbai',75,66],
    ['5/3/2017','mumbai',65,46],
    ['5/1/2017','tokyo',77,70],
    ['5/2/2017','tokyo',88,89],
    ['5/3/2017','tokyo',52,87],
    ],
    columns=['date','city','temp','humidity']
)
df2.pivot_table(index="city",columns='date',aggfunc="sum",margins=True,margins_name='Total')
# Out:
#         humidity                             temp
# date    5/1/2017 5/2/2017 5/3/2017 Total 5/1/2017 5/2/2017 5/3/2017 Total
# city
# mumbai        56       66       46   168       70       75       65   210
# newyork       56       55       45   156       65       68       69   202
# tokyo         70       89       87   246       77       88       52   217
# Total        182      210      178   570      212      231      186   629

# %%
import numpy as np
a=np.array(["foo","foo","foo","foo","bar","bar","bar","bar","foo","foo","foo"])
b=np.array(["one","one","one","two","one","one","one","two","two","two","one"])
c=np.array(["dull","dull","shiny","dull","dull","shiny","shiny","dull","shiny","shiny","shiny"])

pd.crosstab(index=a,columns=[b,c],rownames=['a'],colnames=['b','c'])
# Out:
# b    one        two
# c   dull shiny dull shiny
# a
# bar    1     2    1     0
# foo    2     2    1     2

# %%
df3=pd.DataFrame({'A':{0:'a',1:'b',2:'c'},
                 'B':{0:1,1:3,2:5},
                 'C':{0:2,1:4,2:6}})
pd.melt(df3,id_vars=['A'],value_vars=['B','C'],)
# Out:
#    A variable  value
# 0  a        B      1
# 1  b        B      3
# 2  c        B      5
# 3  a        C      2
# 4  b        C      4
# 5  c        C      6
