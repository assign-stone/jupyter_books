# %%
#### dictionary

# %%
d1 = {'Name':'John', 'Age':24, 'City':'New York'}
d1
# Out:
# {'Name': 'John', 'Age': 24, 'City': 'New York'}

# %% [markdown]
# d1

# %%
d1['Name']
# Out:
# 'John'

# %%
d1['Name'] = 'Amit'
d1
# Out:
# {'Name': 'Amit', 'Age': 24, 'City': 'New York'}

# %%
d1['name'] = 'Sumit'
d1
# Out:
# {'Name': 'Amit', 'Age': 24, 'City': 'New York', 'name': 'Sumit'}

# %%
d1
# Out:
# {'Name': 'John', 'Age': 24, 'City': 'New York'}

# %%
d1.get('Name', 'NA')
# Out:
# 'Amit'

# %%
d1['Gender']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-1988429d5b9f> in <cell line: 0>()
# ----> 1 d1['Gender']
#
# KeyError: 'Gender'

# %%
d1.get('gender')

# %%
d1.get('gender', 'This key is not available')
# Out:
# 'This key is not available'

# %%
d1
# Out:
# {'Name': 'Amit', 'Age': 24, 'City': 'New York', 'name': 'Sumit'}

# %%
list(d1.keys())
# Out:
# ['Name', 'Age', 'City', 'name']

# %%
list(d1.values())
# Out:
# ['Amit', 24, 'New York', 'Sumit']

# %%
list(d1.items())
# Out:
# [('Name', 'Amit'), ('Age', 24), ('City', 'New York'), ('name', 'Sumit')]

# %%
d1.popitem()
d1
# Out:
# {'Name': 'Amit', 'Age': 24, 'City': 'New York'}

# %%
d1
# Out:
# {'Name': 'Amit', 'Age': 24, 'City': 'New York'}

# %%
d1.pop('City')
# Out:
# 'New York'

# %%
d1
# Out:
# {'Name': 'Amit', 'Age': 24}

# %%
d2 = {"Gender":'Male', 'Age':30}
d2
# Out:
# {'Gender': 'Male', 'Age': 30}

# %%
d1
# Out:
# {'Name': 'Amit', 'Age': 24}

# %%
d1.update(d2)

# %%
d1
# Out:
# {'Name': 'Amit', 'Age': 30, 'Gender': 'Male'}

# %%
d3 = {'Name':'John', 'weight':70}

# %%
d1|d3
# Out:
# {'Name': 'John', 'Age': 30, 'Gender': 'Male', 'weight': 70}

# %%
d1
# Out:
# {'Name': 'Amit', 'Age': 30, 'Gender': 'Male'}

# %%
# Out:
# {'a': None, 'b': None}

# %%
d1 = d1|d3

# %%
d1
# Out:
# {'Name': 'John', 'Age': 30, 'Gender': 'Male', 'weight': 70}

# %%
d4 = {}
d4.fromkeys(['a', 'b'])
# Out:
# {'a': None, 'b': None}

# %%
student_db = {}

# %%
student_db = student_db.fromkeys(['Name','Age', 'Std', 'Roll No'])

# %%
student_db['Name'] = 'John'

# %%
contact_details = {
    'Name' : 'Amit',
    'Phone' : [97936389, 936535719]

}

# %%
contact_details = {
    'Name' : 'Amit',
    'Phone' : {'Mob': 999989898, 'landline': 254675}
}

# %%
contact_details['Phone']['landline']
# Out:
# 254675

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 d1[0]
#
# KeyError: 0

# %%
nested_dict = {
    'first_level_key': {
        'second_level_key': {
            'third_level_key': 'value'
        }
    }
}

# %%
nested_dict['first_level_key']['second_level_key']['third_level_key']
# Out:
# 'value'

# %%
contact_details = {
    'Name' : 'Amit',
    'Phone' : {'Mob': 999989898, 'landline': 254675}
}

# %%
contact_details['Phone']['Mob'] = '+91-' + str(contact_details['Phone']['Mob'])

# %%
contact_details
# Out:
# {'Name': 'Amit', 'Phone': {'Mob': '+91-999989898', 'landline': 254675}}

# %%
# 4 tier contact details dictionary with complex dictionaries and list in values
contact_details = {
    'Name' : 'Amit',
    'Phone' : {'Mob': 999989898, 'landline': 254675},
    'Address' : {
        'Street': 'MG Road',
        'City': 'Bangalore',
        'State': 'Karnataka',
        'Country': 'India'
    },
    'Hobbies' : ['Reading', 'Traveling', 'Cooking']
}

# %%
contact_details['Hobbies'][-1]='Trekking'

# %%
contact_details
# Out:
# {'Name': 'Amit',
#  'Phone': {'Mob': 999989898, 'landline': 254675},
#  'Address': {'Street': 'MG Road',
#   'City': 'Bangalore',
#   'State': 'Karnataka',
#   'Country': 'India'},
#  'Hobbies': ['Reading', 'Traveling', 'Trekking']}

# %%
# 4 tier contact details dictionary with complex dictionaries and list in values
contact_details = {
    'Name' : 'Amit',
    'Phone' : {'Mob': 999989898, 'landline': 254675},
    'Address' : {
        'Street': 'MG Road',
        'City': 'Bangalore',
        'State': 'Karnataka',
        'Country': 'India'
    },
    'Hobbies' : ('Reading', 'Traveling', 'Cooking')
}

# %%
nd = list(contact_details['Hobbies'])

# %%
nd[-1]='Trekking'

# %%
contact_details['Hobbies']= tuple(nd)

# %%
contact_details
# Out:
# {'Name': 'Amit',
#  'Phone': {'Mob': 999989898, 'landline': 254675},
#  'Address': {'Street': 'MG Road',
#   'City': 'Bangalore',
#   'State': 'Karnataka',
#   'Country': 'India'},
#  'Hobbies': ('Reading', 'Traveling', 'Trekking')}

# %%
a = [1,2,3]
a[-1]=4

# %%
a
# Out:
# [1, 2, 4]

# %%
#  0  1  2  3  4
#  H  E  L  L  O
# -5 -4 -3 -2 -1

# %%
# 4 tier contact details dictionary with complex dictionaries and list in values
details = {
    'Name' : 'Amit',
    'Phone' : 999989898,
    'Hobbies' : ['Reading', 'Traveling', 'Cooking']
}

# %%
details = {
    'Name' : 'Amit',
    'Phone' : 999989898,
    'Hobbies' : ['Roaming','Reading', 'Traveling', 'Cooking']
}
# Out:
# {'Name': 'Amit',
#  'Phone': 999989898,
#  'Hobbies': ['Reading', 'Traveling', 'Cooking']}

# %%
# SETS

# %%
CP = {1,2,3,4,5}

# %%
FP = {4,5,6,7,8}

# %%
CP.intersection(FP)
# Out:
# {4, 5}

# %%
CP.union(FP)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
CP.symmetric_difference(FP)
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
CP.difference(FP)
# Out:
# {1, 2, 3}

# %%
FP.difference(CP)
# Out:
# {6, 7, 8}

# %%
{1,2,3,4,4,4,5,5,6,6}
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
l1 = [1,2,3,4,2,2,4,2,2,5,3,4,6,6,8,3,3]

# %%
len(set(l1))
# Out:
# 7

# %%
set(l1)
# Out:
# {1, 2, 3, 4, 5, 6, 8}

# %%
d1 = set(l1)

# %%
type(d1)
# Out:
# set
