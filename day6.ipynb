# %%
#### tuple

# %%
t1 = (1,2,3,4,'abcd')

# %%
type(t1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-36358d6357dc> in <cell line: 0>()
# ----> 1 type(t1)
#
# NameError: name 't1' is not defined

# %%
t2 = (1)

# %%
type(t2)
# Out:
# int

# %%
t2 = (1,)

# %%
type(t2)
# Out:
# tuple

# %%
l1 = [1]

# %%
type(l1)
# Out:
# list

# %%
t1
# Out:
# (1, 2, 3, 4, 'abcd')

# %%
t1[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[179], line 1
# ----> 1 t1[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
tol = ([1,2,3], [4,5,6])

# %%
tol[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[181], line 1
# ----> 1 tol[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
tol = ([1,2,3], [4,5,6])

# %%
tol
# Out:
# ([1, 2, 3], [4, 5, 6])

# %%
tol[0][0] = 100

# %%
tol
# Out:
# ([100, 2, 3], [4, 5, 6])

# %%
lot = [(1,2,3), (4,5,6)]

# %%
lot[0] = 100

# %%
lot
# Out:
# [100, (4, 5, 6)]
